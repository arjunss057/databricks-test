# %%
print("Git notebook created")

# %%
spark.read.table("emissions.default.emissions_data").display()

# %%
print("Git crendentials updates")

# %%
print("Add another edit")

# %%
# if x===10

# %%
# testing link ci pipeline.
def my_function():


    '''
    This is a function
    '''
    x = 10      # poor indentation
print("hello")
y = 5       # variables are defined but never used
